# %%
import pandas as pd

# Read CSV file
data = pd.read_csv(".csv")

# Display first 10 rows
print(data.head(10))

# Get dataset information
print(data.info())

# Check for missing values
print(data.isnull())
